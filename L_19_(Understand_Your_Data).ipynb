# %% [markdown]
# <a href="https://colab.research.google.com/github/sammywenthikingwithshroomtrolls/ML_L/blob/main/L_19_(Understand_Your_Data).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.sample()
# Out:
#    PassengerId  Survived  Pclass  \
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch  Ticket     Fare Cabin Embarked
# 8      2  347742  11.1333   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# The output np.int64(0) means that there are zero duplicate rows in your DataFrame df. The df.duplicated() method returns a boolean Series indicating whether each row is a duplicate of a previous row. When you call .sum() on this boolean Series, True values are treated as 1 and False values as 0, effectively counting the number of duplicate rows. So, np.int64(0) tells you that no rows were found to be duplicates, and np.int64 indicates that the result is a 64-bit integer from the NumPy library.

# %%
print(df['Name'].duplicated().sum())

# To see the actual duplicate names:
df[df['Name'].duplicated(keep=False)].sort_values('Name')
# Out:
# 0
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# If you want to count duplicate values for *all* columns, you can iterate through them:

# %%
for column in df.columns:
    duplicates_count = df[column].duplicated().sum()
    if duplicates_count > 0:
        print(f"Column '{column}' has {duplicates_count} duplicate values.")
# Out:
# Column 'Survived' has 889 duplicate values.
# Column 'Pclass' has 888 duplicate values.
# Column 'Sex' has 889 duplicate values.
# Column 'Age' has 802 duplicate values.
# Column 'SibSp' has 884 duplicate values.
# Column 'Parch' has 884 duplicate values.
# Column 'Ticket' has 210 duplicate values.
# Column 'Fare' has 643 duplicate values.
# Column 'Cabin' has 743 duplicate values.
# Column 'Embarked' has 887 duplicate values.

# %% [markdown]
# You can also get the count of unique values in each column to understand the distribution:

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df.corr(numeric_only=True)['Survived']
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64

# %% [markdown]
# This code calculates the correlation of all numerical columns in your DataFrame (df) with the 'Survived' column.

# %% [markdown]
# numeric_only=True: This argument tells df.corr() to only include numerical columns when calculating correlations. This prevents the ValueError you encountered earlier by skipping columns like 'Name' or 'Ticket' that contain text.
